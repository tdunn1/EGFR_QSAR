# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer

from rdkit import Chem
from rdkit.Chem import Descriptors, PandasTools, Descriptors3D, rdDistGeom

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

import matplotlib.cm as cm
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.cluster import KMeans

# %%
df = pd.read_csv('EGFR_Chembl_clean.csv')
df.head(5)
# Out:
#   Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 0       CHEMBL271410           NaN                 NaN            378.48
# 1       CHEMBL411243           NaN                 NaN            429.37
# 2       CHEMBL270713           NaN                 NaN            387.29
# 3        CHEMBL54475           NaN                 NaN            301.15
# 4       CHEMBL405772           NaN                 NaN            251.29
#
#    #RO5 Violations  AlogP           Compound Key  \
# 0              0.0   3.21  126, page S27 table 1
# 1              0.0   4.67  109, page S26 table 1
# 2              0.0   3.50  106, page S26 table 1
# 3              0.0   3.53   78, page S25 table 1
# 4              0.0   2.66   72, page S25 table 1
#
#                                    Smiles Standard Type Standard Relation  \
# 0  Cc1cccc(Nc2ncnc3ccncc23)c1NCCCN1CCOCC1          IC50               '='
# 1  CN(C)CCCCCNc1c(Br)cccc1Nc1ncnc2ccncc12          IC50               '='
# ...

# %%
df = df[['Molecule ChEMBL ID','Standardized Smiles','pIC50']]

# %%
desc_dict = {'MolWt': Descriptors.ExactMolWt, 'TPSA': Chem.rdMolDescriptors.CalcTPSA, 'nRotB': Descriptors.NumRotatableBonds,
            'HBD': Descriptors.NumHDonors, 'HBA':Descriptors.NumHAcceptors, 'LogP':Descriptors.MolLogP, 'NumHetAtoms':Descriptors.NumHeteroatoms, 
            'NumHeavyAtoms':Descriptors.HeavyAtomCount, 'NumAliphaticCarbocycles': Descriptors.NumAliphaticCarbocycles, 'NumAliphaticHeterocycles': Descriptors.NumAliphaticCarbocycles,
            'NumAliphaticRings': Descriptors.NumAliphaticRings, 'NumAromaticCarbocycles': Descriptors.NumAromaticCarbocycles, 'NumAromaticHeterocycles': Descriptors.NumAromaticHeterocycles,
            'NumAromaticRings': Descriptors.NumAromaticRings, 'RingCount': Descriptors.RingCount, 'FractionCSP3': Descriptors.FractionCSP3, 'Asphericity': Descriptors3D.Asphericity,
            'Eccentricity': Descriptors3D.Eccentricity, 'InertShpFactor': Descriptors3D.InertialShapeFactor, 'NPR1': Descriptors3D.NPR1, 'NPR2': Descriptors3D.NPR2, 'PMI1': Descriptors3D.PMI1,
            'PMI2': Descriptors3D.PMI2, 'PMI3': Descriptors3D.PMI3, 'RadGyr': Descriptors3D.RadiusOfGyration, 'SphIndex': Descriptors3D.SpherocityIndex}

for i in df.index:
    smi = df.loc[i,'Standardized Smiles']
    mol = Chem.MolFromSmiles(smi) #Smiles have been cleaned up previously, there shouldn't be problems
    mol = Chem.AddHs(mol)
    rdDistGeom.EmbedMolecule(mol)
    for desc in desc_dict:
        try:
            df.loc[i,desc] = desc_dict[desc](mol)
        except:
            df.loc[i,desc] = None

df.head(5)
# Out:
# [18:01:33] UFFTYPER: Unrecognized charge state for atom: 8
# [18:02:41] UFFTYPER: Unrecognized charge state for atom: 31
# [18:02:41] UFFTYPER: Unrecognized charge state for atom: 60
# [18:05:07] UFFTYPER: Unrecognized charge state for atom: 0
# [18:05:07] UFFTYPER: Unrecognized atom type: Zn+2 (0)
# [18:05:21] UFFTYPER: Unrecognized charge state for atom: 1
# [18:05:54] UFFTYPER: Unrecognized charge state for atom: 33
# [18:06:59] UFFTYPER: Unrecognized charge state for atom: 1
# [18:07:42] UFFTYPER: Unrecognized charge state for atom: 22
# [18:08:50] UFFTYPER: Unrecognized charge state for atom: 1
# [18:08:56] UFFTYPER: Unrecognized charge state for atom: 1
# [18:08:58] UFFTYPER: Unrecognized charge state for atom: 1
# [18:10:08] UFFTYPER: Unrecognized charge state for atom: 1
# [18:10:08] UFFTYPER: Unrecognized charge state for atom: 1
# [18:12:02] UFFTYPER: Unrecognized charge state for atom: 1
# [18:13:41] UFFTYPER: Unrecognized charge state for atom: 1
# ...

# %%
df.dropna(axis = 'columns', how = 'all', inplace = True)
desc_array = df.iloc[:,3:].values

if np.isnan(desc_array).any():
    imp = SimpleImputer(missing_values = np.nan, strategy = 'mean')
    imp = imp.fit(desc_array)
    desc_array = imp.transform(desc_array)
desc_array.shape
# Out:
# (5788, 26)

# %%
sc = StandardScaler()
std_array = sc.fit_transform(desc_array)

pca = PCA(n_components = 0.85) #Get components to explain 85% of the explained variance
array_pca = pca.fit_transform(std_array)
var = pca.explained_variance_ratio_
var
# Out:
# array([0.35575289, 0.1753094 , 0.10530502, 0.08831527, 0.06657985,
#        0.04780069, 0.03924007])

# %%
cum_var = np.cumsum(var)

pca_vects = list(range(1,len(var)+1)) 
plt.bar(pca_vects, var, alpha = 0.5, align = 'center', label = 'Explained variance by singular value')
plt.step(pca_vects, cum_var, where = 'mid', label = 'Cumulative explained variance')
plt.ylabel('Explained variance ratio')
plt.xlabel('Principal component')
plt.ylim(0.0,1.50)
plt.tight_layout()
plt.savefig('explained_variance.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
X = array_pca[:,:3]
X_max = np.amax(X,axis = 0)
X_min = np.amin(X,axis = 0)
scl_X = X/(X_max - X_min)

# %%
k_choice = list(range(2,11))
km_collection = {} #save y_km

for k in k_choice:
    km = KMeans(n_clusters = k, init = 'k-means++', n_init = 10, max_iter = 300, tol = 1e-04, random_state = 0)
    y_km = km.fit_predict(scl_X)
    km_collection[f'{k}_clusters'] = y_km
    cluster_labels = np.unique(y_km)
    clust_nums = cluster_labels.shape[0]
    sil_vals = silhouette_samples(scl_X, y_km, metric = 'euclidean')
    y_bottom, y_upper = 0,0
    yticks = []
    
    for i,j in enumerate(cluster_labels):
        j_sil_vals = sil_vals[y_km == j]
        j_sil_vals.sort()
        y_upper += len(j_sil_vals)
        color = cm.jet(float(i)/clust_nums)
        plt.barh(range(y_bottom, y_upper), j_sil_vals, height = 1, edgecolor = 'none', color = color)
        yticks.append((y_bottom + y_upper)/2)
        y_bottom += len(j_sil_vals)
    
    sil_avg = np.mean(sil_vals)
    plt.axvline(sil_avg, color = 'red', linestyle = '--')
    plt.yticks(yticks, cluster_labels + 1)
    plt.title(f'The average silhouette value for {k} clusters is {round(sil_avg,3)}')
    plt.ylabel('Cluster')
    plt.xlabel("Silhouette score")
    plt.tight_layout()
    plt.show()

# %%
color = ['red','blue', 'purple']
for c in range(3):
    choice = km_collection['2_clusters']
    plt.scatter(scl_X[choice == c,0], scl_X[choice == c, 1], color = color[c] )
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.to_csv('egfr_chembl_w_3d_desc.csv', index = False)
